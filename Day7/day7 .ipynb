# %%
with open('input.txt') as file:
    lines = file.readlines()

# separate tokens and remove trailing whitespace
lines = [line.strip().split(" ") for line in lines]

# %%
# Construct classes to save our files and directories
class Directory():
    name: str
    size: int
    contents: dict

    def __init__(self, name: str, parent=None):
        self.name = name
        self.contents = {}
        self.parent = parent
        self.size = None

    def __str__(self):
        return f"- {self.name} (dir)"

    def compute_size(self):
        """
        recursively compute the size of this directory and all subdirectories
        """
        self.size=0

        for item in self.contents:
            item=self.contents[item]
            if item.size == None:
                item.compute_size()
            self.size+=item.size  


class File():
    name: str
    size: int

    def __init__(self, name: str, size: int):
        self.name = name
        self.size = size

    def __str__(self):
        return f"- {self.name} (file, size={self.size})"

# %%
# Initialise directory structure 
current_tree = ["/"]
current_dir = Directory("/")
root_dir = current_dir

# go through each line, handle cd and ls commands
for i, line in enumerate(lines):
    if line[0] != "$": # If not a command, skip the line. It is handled in ls command handling
        continue
    if line[1] == "cd":
        target = line[2]
        if target == "..": # Go back up a level
            current_tree.pop()
            current_dir = current_dir.parent
        elif target == current_tree[-1]:
            pass
        else:
            target+="_dir" # Mark directories (and later files) to handle duplicate naming
            current_tree.append(target)
            if target in current_dir.contents:
                current_dir = current_dir.contents[target]
            else:
                current_dir = Directory(target, current_dir)
    else:
        for j, new_line in enumerate(lines[i+1:]): # If an ls command is receives, scan lines until a new command is found. everything in between is directories or files to parse
            if new_line[0] == "$":
                contents = lines[i+1:j+i+1]
                break
            contents = lines[i+1:j+i+2] # To handle the end of file, where no new command is found after the last output
        for dir_or_size, name in contents:
            if dir_or_size == "dir":
                if not (name+"_dir") in current_dir.contents:
                    current_dir.contents[name+"_dir"] = Directory(name, current_dir)
            else:
                if not (name+"_file") in current_dir.contents:
                    current_dir.contents[name+"_file"] = File(name, int(dir_or_size))

# %%
def recursive_folder_printer(dir: Directory, indent: int = 0, to_print=False):
    """
    Recursively goes through and prints the folder tree, adding indentation to matchh the formatting on the Advent of Code website
    """
    output = " "*indent + dir.__str__()+"\n"
    for item in dir.contents:
        item = dir.contents[item]
        if issubclass(type(item), Directory):
            output += recursive_folder_printer(item, indent+2) 
        else:
            output += " "*(indent+2) + item.__str__()+"\n"
    if not to_print:
        return output
    else:
        print(output)


recursive_folder_printer(root_dir, to_print=True)
# Out:
# - / (dir)
#   - ddgtnw (dir)
#     - gftgshl (dir)
#       - mtshhn (dir)
#         - fsclsm (file, size=244930)
#         - vnnf (file, size=197930)
#       - smnslwd (dir)
#         - dbtvp.mbr (file, size=205127)
#         - grct (dir)
#           - jjq.hjd (file, size=20977)
#         - hcjtjptg (file, size=270601)
#         - lsqvg.zmm (file, size=146538)
#         - vnnf (file, size=310443)
#         - vqms (file, size=84541)
#       - znbs (dir)
#         - pjrpqc.gwh (file, size=192316)
#         - tnqpmbjf.prg (file, size=5233)
#     - grct (dir)
#       - qzlmfj.lhc (file, size=297156)
#       - vnnf (file, size=104088)
#     - tbqpqfgd.wvz (file, size=57336)
#     - vqms (file, size=267191)
#     - wtgzgmvr (dir)
#       - cfvjph (dir)
#         - tlms (file, size=201215)
#       - jzdqctm (dir)
#         - hnbjcm (dir)
#           - ddgtnw.tpg (file, size=147907)
#           - hgh (dir)
#             - smnslwd.hnd (file, size=64701)
#           - qjpfhmw.gts (file, size=107668)
#           - qvnbfdq (dir)
#             - dzbfsf.qsr (file, size=36206)
#             - dzfpqb (dir)
#               - dzbfsf.mwc (file, size=259317)
#               - rtgrs.hff (file, size=36195)
#             - rvdlmnqv (dir)
#               - smnslwd (dir)
#                 - gflcq (file, size=141659)
#                 - mwszdwvg (file, size=315323)
#             - tlms.jgl (file, size=13989)
#             - vqms (file, size=145493)
#           - tlms (dir)
#             - gwws.zcb (file, size=263149)
#           - wlvg (dir)
#             - vqms (file, size=42151)
#         - jjq.hjd (file, size=112648)
#         - lhzjrmsd (file, size=319899)
#         - pclps (file, size=118481)
#         - pfnmnm (file, size=226538)
#         - vdzsn (dir)
#           - smnslwd.hzc (file, size=301547)
#         - wmvd (file, size=148960)
#         - zvh (dir)
#           - bsnmdtzq.mjp (file, size=111901)
#       - slcz (file, size=153202)
#   - dtmbp (dir)
#     - cscpfcjv (dir)
#       - qzcffqvp (file, size=260848)
#     - hdjs (dir)
#       - tlms (dir)
#         - fwpwgz (file, size=174135)
#     - jcrb (dir)
#       - nqtvhszf (file, size=77666)
#       - smnslwd (file, size=198488)
#       - vnnf (file, size=40032)
#     - spmc (dir)
#       - hhwzwqzq (dir)
#         - mrlnrp.nqs (file, size=43088)
#         - vnnf (file, size=206555)
#       - hlgvsbg (file, size=319757)
#       - jbrftqj (dir)
#         - flb (file, size=296407)
#         - fnbvwh.lcf (file, size=315927)
#     - spwsfpww (dir)
#       - ddgtnw (dir)
#         - gqddds (file, size=133732)
#         - grct (dir)
#           - fvnm (file, size=18055)
#         - lslgfrm.fct (file, size=240907)
#         - rtgrs.hff (file, size=64110)
#         - tlms (dir)
#           - vqms (file, size=54154)
#         - zvwjph.svd (file, size=275504)
#       - hzb (dir)
#         - hmdszw (file, size=178568)
#         - pzsfzr.zqz (file, size=132701)
#         - smnslwd (dir)
#           - dtcrb.tzw (file, size=286526)
#           - smnslwd (file, size=214568)
#       - smnslwd (dir)
#         - ccmmrv.wgs (file, size=118657)
#       - smnslwd.crg (file, size=74678)
#       - tlms (file, size=130878)
#       - tlms.hjr (file, size=239208)
#   - dzbfsf (dir)
#     - grct.lbw (file, size=30773)
#     - jttqnbvn (dir)
#       - jjq.hjd (file, size=9663)
#     - pmdjrf.nqc (file, size=188768)
#     - ptbps (dir)
#       - jzfs.hpq (file, size=132576)
#       - pwclsbw (dir)
#         - dzbfsf (dir)
#           - smnslwd.jcg (file, size=157147)
#     - tllwm (dir)
#       - pcbgr (dir)
#         - grct (dir)
#           - hcstcmpz (file, size=155740)
#           - rtgrs.hff (file, size=156312)
#           - vnnf (file, size=317800)
#         - gvlc.ptr (file, size=65990)
#         - jtqg (dir)
#           - rtgrs.hff (file, size=151962)
#           - vwzsf (file, size=181794)
#         - pljrmjb.hld (file, size=108430)
#         - smtbvvpn (dir)
#           - fgqp.mhf (file, size=272000)
#           - mqgzwzn (dir)
#             - rhp (dir)
#               - jjq.hjd (file, size=297744)
#           - mspltflh (dir)
#             - rlwp.phz (file, size=32927)
#             - vlpzz (file, size=109360)
#           - smnslwd (dir)
#             - vqjgbzd.glg (file, size=172760)
#           - vnnf (file, size=21242)
#           - vzjfv (dir)
#             - dcrlnllf (dir)
#               - thrvjqmj.smd (file, size=19043)
#             - ddgtnw (dir)
#               - fdh.pls (file, size=301193)
#             - pjhnl (dir)
#               - dqfwn.zhg (file, size=305148)
#               - dzbfsf (dir)
#                 - bdmbnm.zpl (file, size=227330)
#                 - cfmhqlhp.qvj (file, size=232365)
#               - smnslwd.nzj (file, size=34622)
#             - twfpbs (dir)
#               - rfn (dir)
#                 - grct (file, size=72138)
#               - vdr (dir)
#                 - vqms (file, size=19296)
#           - wnbtllq (dir)
#             - grct.vmq (file, size=283471)
#             - sqqj (file, size=285265)
#             - trgqdwsc.zjc (file, size=248581)
#         - vqjdpt (dir)
#           - hprsbjzw.lnr (file, size=271132)
#         - vqms (file, size=130683)
#       - smnslwd (dir)
#         - bcg.vwj (file, size=4812)
#         - ddgtnw (dir)
#           - fsclsm (file, size=303604)
#           - jlpzljjl.vzw (file, size=71614)
#           - mzlj.qjz (file, size=110905)
#           - pnhjdbnt (file, size=56751)
#         - pwl.frb (file, size=30986)
#         - tlms (dir)
#           - bpnhvpdf.spq (file, size=36089)
#           - ddgtnw (dir)
#             - hwnfv (dir)
#               - fzrj (file, size=224423)
#             - jsdmffq (dir)
#               - dzbfsf (dir)
#                 - zrfjlcg.sct (file, size=283246)
#             - ndwhj (file, size=268127)
#             - qzlfsmm (file, size=255789)
#             - vnnf (file, size=230625)
#           - grct (dir)
#             - sgpc.wfv (file, size=40705)
#           - jjq.hjd (file, size=97469)
#           - jlz (dir)
#             - vrcb (dir)
#               - gctvnv.rpb (file, size=223815)
#           - nhvvs (dir)
#             - rtgrs.hff (file, size=10109)
#           - ptzptl (dir)
#             - chvn (dir)
#               - cbp (file, size=314968)
#               - ddgtnw (dir)
#                 - dzbfsf.tmf (file, size=19170)
#                 - wqbdcw (file, size=160727)
#               - ddgtnw.ppr (file, size=282139)
#               - vnnf (file, size=121887)
#               - wvrzs (dir)
#                 - vnnf (file, size=263372)
#             - grct (file, size=225860)
#             - hsp (dir)
#               - dzbfsf (dir)
#                 - ntmzsm (dir)
#                   - drbl (dir)
#                     - wccppjd.tcg (file, size=244040)
#                   - frnvqp (dir)
#                     - pqwqbrdw (file, size=196291)
#                   - qhqss.hnm (file, size=258006)
#               - pcs (dir)
#                 - bvmnrf (file, size=102603)
#                 - tlms (file, size=219969)
#               - rjvmwmgm (dir)
#                 - ddgtnw (file, size=73837)
#                 - tlms (dir)
#                   - vqms (file, size=183532)
#                 - tnpfpcz (dir)
#                   - jjn (dir)
#                     - nlmt (dir)
#                       - mzdcb.gtf (file, size=132838)
#                   - rtgrs.hff (file, size=274527)
#                   - ztpd (file, size=97897)
#                 - vnnf (file, size=247155)
#                 - zmvwl (dir)
#                   - zzdl.lqq (file, size=184809)
#               - rtgrs.hff (file, size=179166)
#               - sgb.gjc (file, size=284238)
#               - smlqjjbt.pfb (file, size=44485)
#               - vqms (file, size=260588)
#             - nglr (dir)
#               - clfrgzv.lsh (file, size=216870)
#               - ddgtnw (dir)
#                 - zfdts (dir)
#                   - grct (file, size=13693)
#               - mhpgvbh.phg (file, size=22735)
#               - vqms (file, size=200235)
#               - wjrzwlp (file, size=84345)
#               - ztbjwv (dir)
#                 - zzrsvbg (dir)
#                   - ddgtnw (dir)
#                     - tlms.hrh (file, size=258910)
#             - qgbbv (dir)
#               - crc (dir)
#                 - ffg (file, size=257354)
#                 - jjq.hjd (file, size=258517)
#               - prszvcp (dir)
#                 - fnwgcvw.dbg (file, size=279284)
#                 - grct.ssc (file, size=201788)
#                 - mtlr (dir)
#                   - vztmrn (dir)
#                     - dzbfsf (file, size=84994)
#               - qwrnllw (dir)
#                 - nsrhgbt (dir)
#                   - smnslwd (dir)
#                     - rtgrs.hff (file, size=128046)
#                   - vsnmq (dir)
#                     - zpqp (file, size=15634)
#               - rtqqp.wfv (file, size=151124)
#               - vnnf (file, size=291754)
#               - wgsjgqm.zrm (file, size=279433)
#             - swlgd.cjm (file, size=64084)
#             - tlms (dir)
#               - rtgrs.hff (file, size=240233)
#           - rsqtp (dir)
#             - grct (dir)
#               - ddgtnw (dir)
#                 - hzpr (file, size=235401)
#                 - smnslwd.pqr (file, size=107837)
#               - rtgrs.hff (file, size=27078)
#             - hcsjjss (dir)
#               - jhhw (dir)
#                 - mcmndtb.mjj (file, size=282291)
#               - nptmmjz.pgj (file, size=18002)
#               - tlms (dir)
#                 - tlms.ghp (file, size=159577)
#           - sgbnjmwq (dir)
#             - ddgtnw (dir)
#               - vnnf (file, size=168852)
#               - vqms (file, size=63729)
#             - qfc (dir)
#               - ftjjdg (file, size=321148)
#               - mlp.ssf (file, size=185489)
#               - tlms (file, size=195188)
#             - tlms.mdr (file, size=34331)
#           - smnslwd (dir)
#             - dzbfsf (dir)
#               - dvvcg (dir)
#                 - bsswp (dir)
#                   - gpzmg (file, size=189827)
#               - dznc (dir)
#                 - smnslwd (file, size=3424)
#               - hpzg.rwm (file, size=51706)
#               - vqms (file, size=179994)
#             - grct.vmc (file, size=102016)
#             - gtjgtd (dir)
#               - ddgtnw (file, size=152369)
#             - pbdh (file, size=41304)
#             - tlms.tcf (file, size=94958)
#             - vqms (file, size=178471)
#         - vrwwh (dir)
#           - grct.hgj (file, size=308054)
#         - wwbdc (dir)
#           - zwvtdc (dir)
#             - jqtv (dir)
#               - qdd (dir)
#                 - jjq.hjd (file, size=319798)
#               - smnslwd.hwz (file, size=165188)
#         - wwvvhr (file, size=304408)
#       - svc (dir)
#         - ddgtnw (dir)
#           - tlms.qws (file, size=124212)
#         - fsclsm (file, size=133886)
#         - jjq.hjd (file, size=107226)
#         - wtnbwg.sct (file, size=259031)
#     - vqms (file, size=176302)
#   - fwrlqs (dir)
#     - fsclsm (file, size=45167)
#     - qfq.pqh (file, size=42603)
#   - jjq.hjd (file, size=305959)
#   - qjnnw (dir)
#     - gnlhtvzt (file, size=228764)
#     - grct (dir)
#       - ddgtnw (dir)
#         - zrb (dir)
#           - vnnf (file, size=244157)
#       - vnnf (file, size=98292)
#     - jbs.jnd (file, size=134749)
#     - jjq.hjd (file, size=66187)
#     - mqbbh (dir)
#       - dqmhnq (dir)
#         - dzpn.qsg (file, size=149913)
#         - hmfvzjz (dir)
#           - dzbfsf (dir)
#             - cmgjqnb.wbq (file, size=318705)
#           - hthgs (dir)
#             - ljmsqbvz (dir)
#               - dwrcjrw (file, size=304509)
#         - rtgrs.hff (file, size=198969)
#       - dzbfsf (dir)
#         - ccgfzf.pmh (file, size=116769)
#       - fgzd.rlv (file, size=243785)
#       - grct (dir)
#         - tlms.djc (file, size=246522)
#       - gwlcnf (dir)
#         - vqms (file, size=109428)
#       - rnl (dir)
#         - grct.ptv (file, size=80705)
#         - mtwrqwwl (dir)
#           - wtmgr (dir)
#             - tlms.qmv (file, size=134164)
#             - vqms (file, size=316076)
#             - wnv (file, size=138038)
#             - zsmmhfq (dir)
#               - tlms (file, size=316061)
#         - smnslwd.glg (file, size=174651)
#         - swgp (file, size=30849)
#         - tlms (dir)
#           - fsclsm (file, size=224252)
#           - png.ntp (file, size=4673)
#       - slnqt (dir)
#         - lzzwbcnl (dir)
#           - lhltmghz (dir)
#             - hzhfgsfd (dir)
#               - fsclsm (file, size=36945)
#             - lcj.rsh (file, size=212254)
#         - mpdrjwgl (dir)
#           - ctftvdhl.hzz (file, size=176456)
#           - dzbfsf (file, size=79819)
#           - jvlglnb.dpw (file, size=248804)
#       - smnslwd (dir)
#         - vnnf (file, size=33395)
#       - tlms (dir)
#         - jdvhnpv (dir)
#           - pbwh (dir)
#             - smnslwd (file, size=170653)
#           - vfn (dir)
#             - mcdpp (dir)
#               - dzbfsf.hfn (file, size=294474)
#         - lzsrnpd (file, size=317469)
#         - tlms (dir)
#           - lvqjfj (dir)
#             - rtgrs.hff (file, size=250581)
#       - tlms.cvt (file, size=183073)
#       - wgctf (dir)
#         - crthpg.vlr (file, size=263836)
#         - ddgtnw (dir)
#           - nrfgg (dir)
#             - dzbfsf (file, size=278109)
#             - vqlp.wzt (file, size=301844)
#         - fsclsm (file, size=256310)
#         - mmlw (dir)
#           - gsvfvgn (dir)
#             - ddgtnw.rhb (file, size=4966)
#             - pld.qtc (file, size=85130)
#         - qzq (dir)
#           - pgrgt.jmm (file, size=89149)
#         - tlms (dir)
#           - bzfznn.cdg (file, size=84537)
#         - vqms (file, size=209457)
#     - nlwjn (dir)
#       - ddgtnw (dir)
#         - dzbfsf.jjg (file, size=6932)
#       - psdb (dir)
#         - bhwb.mfn (file, size=196117)
#         - vschrflh.fgp (file, size=127600)
#       - vdmlzzgd (dir)
#         - llch (file, size=5427)
#       - zdzrn (dir)
#         - lfpltz (dir)
#           - sffcz (file, size=157546)
#     - rdn (dir)
#       - fsclsm (file, size=133184)
#       - mrntdh.spz (file, size=186144)
#       - spdlb.vmp (file, size=117372)
#       - vjrjwfwl.zzt (file, size=245469)
#     - shffbpjj (dir)
#       - ccwnzd (dir)
#         - zlwqpwdl.hbh (file, size=143939)
#       - pcqbmmzt (dir)
#         - bqm (file, size=196568)
#         - ddgtnw (dir)
#           - dzbfsf (file, size=320675)
#         - jppm.lfw (file, size=169897)
#         - psm.lml (file, size=188545)
#         - rcnp (dir)
#           - fsclsm (file, size=60088)
#           - grct (dir)
#             - rfgbpbt.mhp (file, size=23004)
#             - vqms (file, size=166737)
#           - qndvg (dir)
#             - smnslwd.tpb (file, size=181934)
#           - rzdzmm.prg (file, size=153481)
#         - sjhrvszs (dir)
#           - gfpzrd (dir)
#             - rltrjpg.lch (file, size=110715)
#             - vnnf (file, size=117420)
#           - rtgrs.hff (file, size=283172)
#           - tlms (dir)
#             - cvcq.lqw (file, size=211543)
#             - tlms (file, size=132575)
#         - vnnf (file, size=83840)
#         - vvh (dir)
#           - bscbv (dir)
#             - smnslwd.pvj (file, size=116170)
#             - vqms (file, size=295190)
#           - djzcnld (dir)
#             - dtnqpfqw.nlj (file, size=6635)
#             - fzpnfnp.jbt (file, size=27153)
#             - rlchrtlw (file, size=164286)
#             - rtgrs.hff (file, size=231430)
#             - wbfqtpjn.vsq (file, size=33326)
#           - grct.tjl (file, size=276126)
#           - nlsstb (dir)
#             - dbpdbtvw (file, size=91522)
#             - nfdgjsp.npf (file, size=221628)
#         - wzcqnz (dir)
#           - fcqwl.nwt (file, size=244122)
#           - grct (dir)
#             - ddgtnw (dir)
#               - drwqt (file, size=287254)
#               - gddwrgh.qls (file, size=90776)
#             - qglfnbds (dir)
#               - qzh (dir)
#                 - bswc (file, size=164079)
#                 - dzbfsf (file, size=207352)
#                 - ftdjsfbg.lbl (file, size=203683)
#                 - sgmtn.llc (file, size=60925)
#                 - wws (dir)
#                   - mjq.fjz (file, size=111099)
#             - wrthr (dir)
#               - ddgtnw (dir)
#                 - dzbfsf (file, size=180911)
#                 - jjq.hjd (file, size=301448)
#                 - mdmc (dir)
#                   - dzbfsf.mcl (file, size=267495)
#                 - nlls (dir)
#                   - jjq.hjd (file, size=221776)
#                 - vqms (file, size=207270)
#                 - wsctbr (dir)
#                   - fsclsm (file, size=93502)
#               - jfv (dir)
#                 - ddgtnw (file, size=129583)
#               - ndwlld (dir)
#                 - gtqc.zvq (file, size=217056)
#               - nsnz (dir)
#                 - jhntl (dir)
#                   - trdnzfz (file, size=103365)
#               - vqql (dir)
#                 - smnslwd.gzj (file, size=201664)
#           - jjq.hjd (file, size=19950)
#           - nwcvl (file, size=296817)
#           - smnslwd (dir)
#             - fsclsm (file, size=318911)
#             - jcvmgzc (dir)
#               - jjq.hjd (file, size=37799)
#             - rtgrs.hff (file, size=101015)
#         - zfctl (dir)
#           - fmfgjw (dir)
#             - ddgtnw.bhf (file, size=159825)
#             - jjq.hjd (file, size=210407)
#           - lbz (dir)
#             - gbcqz.lgw (file, size=206810)
#             - rtgrs.hff (file, size=20178)
#     - spjc (file, size=154029)

# %%
# Go through and fill in all directory sizes
root_dir.compute_size()
root_dir.size
# Out:
# 46975962

# %%
def recursive_dir_lister(dir:Directory):
    """
    Makes a list of all (recursive) subdirectories contained in a directory
    """
    dirs=[dir]
    for item in dir.contents:
        item=dir.contents[item]
        if issubclass(type(item),Directory):
            subdirs=recursive_dir_lister(item)
            dirs+=subdirs

    return dirs

all_directories=recursive_dir_lister(root_dir)

# Make a list of names and sizes for easy searching
dir_name_size=[[dir.name,dir.size] for dir in all_directories]

dir_name_size
# Out:
# [['/', 46975962],
#  ['ddgtnw', 5672556],
#  ['gftgshl', 1678636],
#  ['mtshhn', 442860],
#  ['smnslwd', 1038227],
#  ['grct', 20977],
#  ['znbs', 197549],
#  ['grct', 401244],
#  ['wtgzgmvr', 3268149],
#  ['cfvjph', 201215],
#  ['jzdqctm', 2913732],
#  ['hnbjcm', 1573758],
#  ['hgh', 64701],
#  ['qvnbfdq', 948182],
#  ['dzfpqb', 295512],
#  ['rvdlmnqv', 456982],
#  ['smnslwd', 456982],
#  ['tlms', 263149],
#  ['wlvg', 42151],
#  ['vdzsn', 301547],
#  ['zvh', 111901],
#  ['dtmbp', 4095149],
#  ['cscpfcjv', 260848],
#  ['hdjs', 174135],
#  ['tlms', 174135],
#  ['jcrb', 316186],
#  ['spmc', 1181734],
#  ['hhwzwqzq', 249643],
#  ['jbrftqj', 612334],
#  ['spwsfpww', 2162246],
#  ['ddgtnw', 786462],
#  ['grct', 18055],
#  ['tlms', 54154],
#  ['hzb', 812363],
#  ['smnslwd', 501094],
#  ['smnslwd', 118657],
#  ['dzbfsf', 19354558],
#  ['jttqnbvn', 9663],
#  ['ptbps', 289723],
#  ['pwclsbw', 157147],
#  ['dzbfsf', 157147],
#  ['tllwm', 18659329],
#  ['pcbgr', 4474328],
#  ['grct', 629852],
#  ['jtqg', 333756],
#  ['smtbvvpn', 2934485],
#  ['mqgzwzn', 297744],
#  ['rhp', 297744],
#  ['mspltflh', 142287],
#  ['smnslwd', 172760],
#  ['vzjfv', 1211135],
#  ['dcrlnllf', 19043],
#  ['ddgtnw', 301193],
#  ['pjhnl', 799465],
#  ['dzbfsf', 459695],
#  ['twfpbs', 91434],
#  ['rfn', 72138],
#  ['vdr', 19296],
#  ['wnbtllq', 817317],
#  ['vqjdpt', 271132],
#  ['smnslwd', 13560646],
#  ['ddgtnw', 542874],
#  ['tlms', 11884526],
#  ['ddgtnw', 1262210],
#  ['hwnfv', 224423],
#  ['jsdmffq', 283246],
#  ['dzbfsf', 283246],
#  ['grct', 40705],
#  ['jlz', 223815],
#  ['vrcb', 223815],
#  ['nhvvs', 10109],
#  ['ptzptl', 7421137],
#  ['chvn', 1162263],
#  ['ddgtnw', 179897],
#  ['wvrzs', 263372],
#  ['hsp', 2983981],
#  ['dzbfsf', 698337],
#  ['ntmzsm', 698337],
#  ['drbl', 244040],
#  ['frnvqp', 196291],
#  ['pcs', 322572],
#  ['rjvmwmgm', 1194595],
#  ['tlms', 183532],
#  ['tnpfpcz', 505262],
#  ['jjn', 132838],
#  ['nlmt', 132838],
#  ['zmvwl', 184809],
#  ['nglr', 796788],
#  ['ddgtnw', 13693],
#  ['zfdts', 13693],
#  ['ztbjwv', 258910],
#  ['zzrsvbg', 258910],
#  ['ddgtnw', 258910],
#  ['qgbbv', 1947928],
#  ['crc', 515871],
#  ['prszvcp', 566066],
#  ['mtlr', 84994],
#  ['vztmrn', 84994],
#  ['qwrnllw', 143680],
#  ['nsrhgbt', 143680],
#  ['smnslwd', 128046],
#  ['vsnmq', 15634],
#  ['tlms', 240233],
#  ['rsqtp', 830186],
#  ['grct', 370316],
#  ['ddgtnw', 343238],
#  ['hcsjjss', 459870],
#  ['jhhw', 282291],
#  ['tlms', 159577],
#  ['sgbnjmwq', 968737],
#  ['ddgtnw', 232581],
#  ['qfc', 701825],
#  ['smnslwd', 994069],
#  ['dzbfsf', 424951],
#  ['dvvcg', 189827],
#  ['bsswp', 189827],
#  ['dznc', 3424],
#  ['gtjgtd', 152369],
#  ['vrwwh', 308054],
#  ['wwbdc', 484986],
#  ['zwvtdc', 484986],
#  ['jqtv', 484986],
#  ['qdd', 319798],
#  ['svc', 624355],
#  ['ddgtnw', 124212],
#  ['fwrlqs', 87770],
#  ['qjnnw', 17459970],
#  ['grct', 342449],
#  ['ddgtnw', 244157],
#  ['zrb', 244157],
#  ['mqbbh', 6685330],
#  ['dqmhnq', 972096],
#  ['hmfvzjz', 623214],
#  ['dzbfsf', 318705],
#  ['hthgs', 304509],
#  ['ljmsqbvz', 304509],
#  ['dzbfsf', 116769],
#  ['grct', 246522],
#  ['gwlcnf', 109428],
#  ['rnl', 1419469],
#  ['mtwrqwwl', 904339],
#  ['wtmgr', 904339],
#  ['zsmmhfq', 316061],
#  ['tlms', 228925],
#  ['slnqt', 754278],
#  ['lzzwbcnl', 249199],
#  ['lhltmghz', 249199],
#  ['hzhfgsfd', 36945],
#  ['mpdrjwgl', 505079],
#  ['smnslwd', 33395],
#  ['tlms', 1033177],
#  ['jdvhnpv', 465127],
#  ['pbwh', 170653],
#  ['vfn', 294474],
#  ['mcdpp', 294474],
#  ['tlms', 250581],
#  ['lvqjfj', 250581],
#  ['wgctf', 1573338],
#  ['ddgtnw', 579953],
#  ['nrfgg', 579953],
#  ['mmlw', 90096],
#  ['gsvfvgn', 90096],
#  ['qzq', 89149],
#  ['tlms', 84537],
#  ['nlwjn', 493622],
#  ['ddgtnw', 6932],
#  ['psdb', 323717],
#  ['vdmlzzgd', 5427],
#  ['zdzrn', 157546],
#  ['lfpltz', 157546],
#  ['rdn', 682169],
#  ['shffbpjj', 8672671],
#  ['ccwnzd', 143939],
#  ['pcqbmmzt', 8528732],
#  ['ddgtnw', 320675],
#  ['rcnp', 585244],
#  ['grct', 189741],
#  ['qndvg', 181934],
#  ['sjhrvszs', 855425],
#  ['gfpzrd', 228135],
#  ['tlms', 344118],
#  ['vvh', 1463466],
#  ['bscbv', 411360],
#  ['djzcnld', 462830],
#  ['nlsstb', 313150],
#  ['wzcqnz', 4067852],
#  ['grct', 3049238],
#  ['ddgtnw', 378030],
#  ['qglfnbds', 747138],
#  ['qzh', 747138],
#  ['wws', 111099],
#  ['wrthr', 1924070],
#  ['ddgtnw', 1272402],
#  ['mdmc', 267495],
#  ['nlls', 221776],
#  ['wsctbr', 93502],
#  ['jfv', 129583],
#  ['ndwlld', 217056],
#  ['nsnz', 103365],
#  ['jhntl', 103365],
#  ['vqql', 201664],
#  ['smnslwd', 457725],
#  ['jcvmgzc', 37799],
#  ['zfctl', 597220],
#  ['fmfgjw', 370232],
#  ['lbz', 226988]]

# %%
total=0
for dir in dir_name_size:
    size = dir[1]
    if size <= int(1e5):
        total+=size
        

total # 836968 is too low, 1334506 is correct
# Out:
# 1334506

# %% [markdown]
# # Part 2

# %%
# Computed the required folder size
TOTAL_SPACE = int(7e7)
REQUIRED_SPACE= int(3e7)
available_space=TOTAL_SPACE- root_dir.size
space_to_free=REQUIRED_SPACE-available_space
space_to_free
# Out:
# 6975962

# %%
# Find the smallest folder that satisfies the required folder size
size_to_beat=max([dir[1] for dir in dir_name_size])
for size in [dir[1] for dir in dir_name_size]:
    if size < size_to_beat and size >=space_to_free:
        size_to_beat=size

size_to_beat
# Out:
# 7421137

# %%
# Find and print the directory with the size found previously
_=[print(f"{dir[0]},{dir[1]}") for dir in dir_name_size if dir[1]==size_to_beat]
# Out:
# ptzptl,7421137

# %%
# Do both at once with list comprehension magic
_=[print(f"{dir}, size = {dir.size}") for dir in all_directories if dir.size == min([dir.size for dir in all_directories if dir.size>=space_to_free])]
# Out:
# - ptzptl (dir), size = 7421137

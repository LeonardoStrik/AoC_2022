# %%
from math import floor
NULL_STR = ""

# %%
with open("input.txt") as file:
    lines = file.readlines()

# %%
tokens = [line.strip().split(" ") for line in lines]

# %%
class Monkey():

    def __init__(self, starting_items: list[int], operation: str, test: int, if_true: int, if_false: int):

        self.items = [int(item) for item in starting_items]
        self.operation = operation
        self.test = int(test)
        self.throw_to = [int(if_false), int(if_true)]
        self.times_inspected=0

    def inspect(self, monkeys: list, to_print=True):

        for item in self.items:
            if to_print:
                print(f"Monkey inspects an item with a worry level of {item}.")
            item = eval(self.operation)
            if to_print:
                print(f"Worry level is {self.operation} to {item}.")
            item = int(floor(item/3))
            if to_print:
                print(
                    f"Monkey gets bored with item. Worry level is divided by 3 to {item}.")
            throw_ind = item % self.test == 0
            is_isnt = ["not ", NULL_STR]
            if to_print:
                print(
                    f"Current worry level is {is_isnt[throw_ind]}divisible by {self.test}.")
            target_monkey = self.throw_to[throw_ind]
            if to_print:
                print(
                    f"Item with worry level {item} is thrown to monkey {target_monkey}.")
            monkeys[target_monkey].items.append(item)
            self.times_inspected+=1

        self.items = []

    def __str__(self):
        string = "Monkey:\n"
        string += f"  items: {self.items}\n"
        string += f"  operation: {self.operation}\n"
        string += f"  test: {self.test}\n"
        string += f"  throw to: {self.throw_to}\n"
        return string

# %%
def parse_operation(operation_tokens):
    op = NULL_STR
    for token in operation_tokens:
        op += " "+token
    op = op.replace("old", "item")
    return op

# %%
monkeys = []
for i in range(0, len(tokens), 7):
    monkey_tokens = tokens[i:i+6]
    starting_items = [int(x.replace(",", NULL_STR))
                      for x in monkey_tokens[1][2:]]
    operation = parse_operation(monkey_tokens[2][3:])
    test = monkey_tokens[3][3]
    if_true = monkey_tokens[4][5]
    if_false = monkey_tokens[5][5]
    monkeys.append(Monkey(starting_items, operation, test, if_true, if_false))

_ = [print(monkey) for monkey in monkeys]
# Out:
# Monkey:
#   items: [77, 69, 76, 77, 50, 58]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey:
#   items: [75, 70, 82, 83, 96, 64, 62]
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey:
#   items: [53]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey:
#   items: [85, 64, 93, 64, 99]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey:
#   items: [61, 92, 71]
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey:
#   items: [79, 73, 50, 90]
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey:
#   items: [50, 89]
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey:
#   items: [83, 56, 64, 58, 93, 91, 56, 65]
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]

# %%
n_rounds = 20
for round in range(n_rounds):
    print(f"Round {round+1}:")
    for i, monkey in enumerate(monkeys):
        monkey.inspect(monkeys, False)

    for i, monkey in enumerate(monkeys):
        print("Monkey " + str(i)+"\n")
        print(monkey)
# Out:
# Round 1:
# Monkey 0
#
# Monkey:
#   items: [29, 20, 23, 21, 32, 32, 20, 23]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: [19]
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [29, 22, 32, 22, 34, 1680]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [1240, 2821, 17, 30, 10, 9, 11, 11, 9, 8, 10, 9, 6, 11, 32, 29, 32, 32, 21, 24, 5]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 2:
# Monkey 0
#
# Monkey:
#   items: [22, 32, 22, 34, 1680, 11, 4]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [414, 941, 11, 4, 4, 5, 5, 4, 4, 4, 4, 3, 5, 12, 11, 12, 12, 8, 9, 3]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [4, 9, 10, 9, 14, 14, 9, 10]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: [13]
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 3:
# Monkey 0
#
# Monkey:
#   items: [414, 4, 4, 4, 4, 4, 4, 12, 12, 12, 8, 315, 5, 3, 3, 2, 3, 5, 4, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 4, 4, 4, 6, 6, 4, 4]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [56, 10, 10, 686, 6, 14, 15, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 4:
# Monkey 0
#
# Monkey:
#   items: [2, 4, 4, 4, 6, 6, 4, 4]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [20, 4, 4, 230, 3, 6, 6, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 6, 6, 6, 4, 3, 2, 2, 2, 2, 3, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: [506, 130]
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 5:
# Monkey 0
#
# Monkey:
#   items: [20, 4, 4, 230, 6, 6, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 3, 3, 3, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [85345, 5633, 2, 2, 2, 2, 3, 3, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 6:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [28449, 1879, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [9, 2, 2, 94, 3, 3, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 7:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 9484, 628]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [4, 2, 2, 32, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 8:
# Monkey 0
#
# Monkey:
#   items: [4, 2, 2, 32, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 3865, 257]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 9:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 1289, 87]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 14, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 10:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 431, 30]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 6, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 11:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 6, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [177, 14, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 12:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [60, 6, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 3, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 13:
# Monkey 0
#
# Monkey:
#   items: [60, 6, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 14:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [3, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: [26]
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 15:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 225]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 16:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: [76]
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 17:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [10, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 18:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [4, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 19:
# Monkey 0
#
# Monkey:
#   items: [4, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]
#
# Round 20:
# Monkey 0
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 11
#   test: 5
#   throw to: [5, 1]
#
# Monkey 1
#
# Monkey:
#   items: []
#   operation:  item + 8
#   test: 17
#   throw to: [6, 5]
#
# Monkey 2
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item * 3
#   test: 2
#   throw to: [7, 0]
#
# Monkey 3
#
# Monkey:
#   items: [2, 2, 2, 2, 2, 2, 2, 2, 2, 2]
#   operation:  item + 4
#   test: 7
#   throw to: [2, 7]
#
# Monkey 4
#
# Monkey:
#   items: []
#   operation:  item * item
#   test: 3
#   throw to: [3, 2]
#
# Monkey 5
#
# Monkey:
#   items: []
#   operation:  item + 2
#   test: 11
#   throw to: [6, 4]
#
# Monkey 6
#
# Monkey:
#   items: []
#   operation:  item + 3
#   test: 13
#   throw to: [3, 4]
#
# Monkey 7
#
# Monkey:
#   items: []
#   operation:  item + 5
#   test: 19
#   throw to: [0, 1]

# %%
times_inspected=[monkey.times_inspected for monkey in monkeys]
max1=max(times_inspected)
max2=max([time for time in times_inspected if time< max1])
max1*max2
# Out:
# 57838
